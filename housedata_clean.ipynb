# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("housedata.csv")
df.head()
# Out:
#    PID          Property Address   Property City     House Type  \
# 0    1       1100  CHEYENNE  CIR         MADISON  SINGLE FAMILY
# 1    2           3450  GREER  RD  GOODLETTSVILLE  SINGLE FAMILY
# 2    3  8565  WHITES CREEK  PIKE         JOELTON  SINGLE FAMILY
# 3    4      8560  COOPERTOWN  RD         JOELTON  SINGLE FAMILY
# 4    5    8409  RILEY ADCOCK  RD         JOELTON  SINGLE FAMILY
#
#    Sale Price(USD)  Sale Date   Latitude  Longitude  Zone  Unnamed: 9  \
# 0           304000   9/7/2021  36.252414 -86.670697     6         NaN
# 1           405000  9/17/2021  36.383536 -86.783246     5         NaN
# 2           666500  9/22/2021  36.381169 -86.894571     5         NaN
# 3           620000  9/20/2021  36.380810 -86.906122     5         NaN
# 4           227500  9/17/2021  36.372914 -86.883644     5         NaN
#
#    Unnamed: 10
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.count()
# Out:
# PID                 1463
# Property Address    1463
# Property City       1463
# House Type          1463
# Sale Price(USD)     1463
# Sale Date           1463
# Latitude            1462
# Longitude           1463
# Zone                1463
# Unnamed: 9             0
# Unnamed: 10            0
# dtype: int64

# %%
df.head()
# Out:
#    PID          Property Address   Property City     House Type  \
# 0    1       1100  CHEYENNE  CIR         MADISON  SINGLE FAMILY
# 1    2           3450  GREER  RD  GOODLETTSVILLE  SINGLE FAMILY
# 2    3  8565  WHITES CREEK  PIKE         JOELTON  SINGLE FAMILY
# 3    4      8560  COOPERTOWN  RD         JOELTON  SINGLE FAMILY
# 4    5    8409  RILEY ADCOCK  RD         JOELTON  SINGLE FAMILY
#
#    Sale Price(USD)  Sale Date   Latitude  Longitude  Zone  Unnamed: 9  \
# 0           304000   9/7/2021  36.252414 -86.670697     6         NaN
# 1           405000  9/17/2021  36.383536 -86.783246     5         NaN
# 2           666500  9/22/2021  36.381169 -86.894571     5         NaN
# 3           620000  9/20/2021  36.380810 -86.906122     5         NaN
# 4           227500  9/17/2021  36.372914 -86.883644     5         NaN
#
#    Unnamed: 10
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.loc[(df['House Type'] == 'RESIDENTIAL CONDO') & (df['Sale Price(USD)'] == 34131000)]
# Out:
#      PID       Property Address Property City         House Type  \
# 562  563     1204   49TH  AVE N     NASHVILLE  RESIDENTIAL CONDO
# 563  564     1216   49TH  AVE N     NASHVILLE  RESIDENTIAL CONDO
# 564  565     1212   49TH  AVE N     NASHVILLE  RESIDENTIAL CONDO
# 565  566     1206   49TH  AVE N     NASHVILLE  RESIDENTIAL CONDO
# 566  567     220   FOUNDERS  LN     NASHVILLE  RESIDENTIAL CONDO
# 567  568     216   FOUNDERS  LN     NASHVILLE  RESIDENTIAL CONDO
# 568  569     218   FOUNDERS  LN     NASHVILLE  RESIDENTIAL CONDO
# 569  570     242   FOUNDERS  LN     NASHVILLE  RESIDENTIAL CONDO
# 570  571     240   FOUNDERS  LN     NASHVILLE  RESIDENTIAL CONDO
# 571  572     222   FOUNDERS  LN     NASHVILLE  RESIDENTIAL CONDO
# 572  573     244   FOUNDERS  LN     NASHVILLE  RESIDENTIAL CONDO
# 573  574     246   FOUNDERS  LN     NASHVILLE  RESIDENTIAL CONDO
# 574  575     252   FOUNDERS  LN     NASHVILLE  RESIDENTIAL CONDO
# ...

# %%
df_clean = df.drop(df[(df['PID'] > 563) & (df['PID'] < 621)].index, axis = 0)

# %%
df_clean.loc[(df['House Type'] == 'RESIDENTIAL CONDO') & (df['Sale Price(USD)'] == 34131000)]
# Out:
#      PID    Property Address Property City         House Type  \
# 562  563  1204   49TH  AVE N     NASHVILLE  RESIDENTIAL CONDO
#
#      Sale Price(USD)  Sale Date   Latitude  Longitude  Zone  Unnamed: 9  \
# 562         34131000  9/16/2021  36.162113 -86.845582     3         NaN
#
#      Unnamed: 10
# 562          NaN

# %%
df_clean = df.drop(['Unnamed: 9','Unnamed: 10'], axis=1)
df_clean.head()
# Out:
#    PID          Property Address   Property City     House Type  \
# 0    1       1100  CHEYENNE  CIR         MADISON  SINGLE FAMILY
# 1    2           3450  GREER  RD  GOODLETTSVILLE  SINGLE FAMILY
# 2    3  8565  WHITES CREEK  PIKE         JOELTON  SINGLE FAMILY
# 3    4      8560  COOPERTOWN  RD         JOELTON  SINGLE FAMILY
# 4    5    8409  RILEY ADCOCK  RD         JOELTON  SINGLE FAMILY
#
#    Sale Price(USD)  Sale Date   Latitude  Longitude  Zone
# 0           304000   9/7/2021  36.252414 -86.670697     6
# 1           405000  9/17/2021  36.383536 -86.783246     5
# 2           666500  9/22/2021  36.381169 -86.894571     5
# 3           620000  9/20/2021  36.380810 -86.906122     5
# 4           227500  9/17/2021  36.372914 -86.883644     5

# %%
df_clean = df_clean.dropna()

# %%
df_clean
# Out:
#        PID          Property Address   Property City         House Type  \
# 0        1       1100  CHEYENNE  CIR         MADISON      SINGLE FAMILY
# 1        2           3450  GREER  RD  GOODLETTSVILLE      SINGLE FAMILY
# 2        3  8565  WHITES CREEK  PIKE         JOELTON      SINGLE FAMILY
# 3        4      8560  COOPERTOWN  RD         JOELTON      SINGLE FAMILY
# 4        5    8409  RILEY ADCOCK  RD         JOELTON      SINGLE FAMILY
# ...    ...                       ...             ...                ...
# 1458  1459        4232   DYSANT  ALY     NOLENSVILLE      SINGLE FAMILY
# 1459  1460      1983   CAROTHERS  RD     NOLENSVILLE      SINGLE FAMILY
# 1460  1461          307   MOIRA  CIR     NOLENSVILLE  RESIDENTIAL CONDO
# 1461  1462            4154  ALVA  LN     NOLENSVILLE      SINGLE FAMILY
# 1462  1463       2027  OAK TRAIL  DR     NOLENSVILLE  RESIDENTIAL CONDO
#
#       Sale Price(USD)  Sale Date   Latitude  Longitude  Zone
# ...

# %%
df_clean = df_clean.drop(df[(df['PID'] > 139) & (df['PID'] < 145)].index, axis = 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-116-a22f9cca321a> in <module>
# ----> 1 df_clean = df_clean.drop(df[(df['PID'] > 139) & (df['PID'] < 145)].index, axis = 0)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df_clean = df_clean.drop(df[(df['PID'] == 157) & (df['PID'] == 158)].index, axis = 0)

# %%
df_clean = df_clean.drop(df[(df['PID'] > 139) & (df['PID'] < 145)].index, axis = 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-118-a22f9cca321a> in <module>
# ----> 1 df_clean = df_clean.drop(df[(df['PID'] > 139) & (df['PID'] < 145)].index, axis = 0)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df_clean = df_clean.drop(df[(df['PID'] == 72)].index, axis = 0)

# %%
df_clean = df_clean.drop(df[(df['PID'] == 192)].index, axis = 0)

# %%
df_clean = df_clean.drop(df[(df['PID'] == 199)].index, axis = 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-c30fce1a3775> in <module>
# ----> 1 df_clean = df_clean.drop(df[(df['PID'] == 199)].index, axis = 0)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df_clean = df_clean.drop(df[(df['PID'] == 245)].index, axis = 0)

# %%
df_clean = df_clean.drop(df[(df['PID'] == 286)].index, axis = 0)

# %%
df_clean = df_clean.drop(df[(df['PID'] == 310) & (df['PID'] == 311)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 400)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 415)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 428)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 464) & (df['PID'] == 472)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 499) & (df['PID'] == 500)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] > 517) & (df['PID'] < 526)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] > 563) & (df['PID'] < 593)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] > 593) & (df['PID'] < 604)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] > 604) & (df['PID'] < 614)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] > 614) & (df['PID'] < 621)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] > 626) & (df['PID'] < 650)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] > 663) & (df['PID'] < 668)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 669)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 696)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] > 707) & (df['PID'] < 711)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] > 717) & (df['PID'] < 720)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] > 743) & (df['PID'] < 747)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 761)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 765) & (df['PID'] == 766)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 780)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 785)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 803)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 807) & (df['PID'] == 808)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 829) & (df['PID'] == 831)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] > 857) & (df['PID'] < 861)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 894)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 903)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 964)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] > 967) & (df['PID'] < 971)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 989)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 1008)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 1029)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 1057)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 1060)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 1075)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 1100)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 1111)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 1135)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 1200)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 1204)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 1273)].index, axis = 0)
df_clean = df_clean.drop(df[(df['PID'] == 1328)].index, axis = 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-125-413a10f9c673> in <module>
#       1 df_clean = df_clean.drop(df[(df['PID'] == 310) & (df['PID'] == 311)].index, axis = 0)
# ----> 2 df_clean = df_clean.drop(df[(df['PID'] == 400)].index, axis = 0)
#       3 df_clean = df_clean.drop(df[(df['PID'] == 415)].index, axis = 0)
#       4 df_clean = df_clean.drop(df[(df['PID'] == 428)].index, axis = 0)
#       5 df_clean = df_clean.drop(df[(df['PID'] == 464) & (df['PID'] == 472)].index, axis = 0)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ...

# %%
df_clean.count()
# Out:
# PID                 1324
# Property Address    1324
# Property City       1324
# House Type          1324
# Sale Price(USD)     1324
# Sale Date           1324
# Latitude            1324
# Longitude           1324
# Zone                1324
# dtype: int64

# %%
#Exporting the File to CSV
df_clean.to_csv('housedata_cleaned.csv')
